# %%
S3_Key_id='AKIAQXCR5B4B6MUJUPMR'

S3_Secret_key='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'

S3_file = 'raw_data/WFIGS_Perimeters_Full_History/WFIGS_-_Wildland_Fire_Perimeters_Full_History.csv'

# %%
import boto3
import pandas as pd
from operator import methodcaller
import numpy as np
import datetime

# %%
def pull_data(Key_id, Secret_key, file):

    BUCKET_NAME = "gtown-wildfire-ds"
    OBJECT_KEY = file
    
    client = boto3.client(
        's3',
        aws_access_key_id= Key_id,
        aws_secret_access_key= Secret_key)

    obj = client.get_object(Bucket= BUCKET_NAME, Key= OBJECT_KEY) 
    
    file_df = pd.read_csv(obj['Body'])
    
    return (file_df)

data = pull_data(S3_Key_id,S3_Secret_key,S3_file)

data
# Out:
# /var/folders/fp/yk0vdn2x3czcnj314mr51lzr0000gn/T/ipykernel_89140/3136566559.py:13: DtypeWarning: Columns (40,69,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_df = pd.read_csv(obj['Body'])
#        OBJECTID poly_IncidentName           poly_FeatureCategory  \
# 0           127           Coleman  Wildfire Daily Fire Perimeter
# 1           128          Patrick   Wildfire Daily Fire Perimeter
# 2           129           Low Top  Wildfire Daily Fire Perimeter
# 3           130           Sloan 2  Wildfire Daily Fire Perimeter
# 4           133       Bloody nose  Wildfire Daily Fire Perimeter
# ...         ...               ...                            ...
# 13020     19336       Sandy Creek  Wildfire Daily Fire Perimeter
# 13021     19337       Muddy Pines  Wildfire Daily Fire Perimeter
# 13022     19338         Polk 4984  Wildfire Daily Fire Perimeter
# 13023     19339         Bypass 35  Wildfire Daily Fire Perimeter
# ...

# %% [markdown]
# ## Note: Col 'OBJECTID'
#
#
# -Consider a unique id
#
# -always pull this col when making sub df's

# %%
list(data.columns)
# Out:
# ['OBJECTID',
#  'poly_IncidentName',
#  'poly_FeatureCategory',
#  'poly_MapMethod',
#  'poly_GISAcres',
#  'poly_CreateDate',
#  'poly_DateCurrent',
#  'poly_PolygonDateTime',
#  'poly_Acres_AutoCalc',
#  'poly_GlobalID',
#  'poly_Source',
#  'irwin_ABCDMisc',
#  'irwin_ADSPermissionState',
#  'irwin_CalculatedAcres',
#  'irwin_ContainmentDateTime',
#  'irwin_ControlDateTime',
#  'irwin_DailyAcres',
#  'irwin_DiscoveryAcres',
#  'irwin_DispatchCenterID',
#  'irwin_EstimatedCostToDate',
#  'irwin_FFReportApprovedByTitle',
#  'irwin_FFReportApprovedByUnit',
#  'irwin_FFReportApprovedDate',
#  'irwin_FireBehaviorGeneral',
#  'irwin_FireBehaviorGeneral1',
#  'irwin_FireBehaviorGeneral2',
#  'irwin_FireBehaviorGeneral3',
#  'irwin_FireCause',
#  'irwin_FireCauseGeneral',
#  'irwin_FireCauseSpecific',
#  'irwin_FireCode',
#  'irwin_FireDepartmentID',
#  'irwin_FireDiscoveryDateTime',
#  'irwin_FireMgmtComplexity',
#  'irwin_FireOutDateTime',
#  'irwin_FSConfinePercent',
# ...

# %%
import pandas as pd
import datetime

# %%
df = df[df['poly_Acres_AutoCalc'] > 1]

df
# Out:
#        OBJECTID  poly_GISAcres  poly_Acres_AutoCalc  irwin_CalculatedAcres  \
# 0           127     562.913504           562.911767                574.424
# 2           129       0.300000             2.850691                    NaN
# 3           130      44.300517            44.300352                    NaN
# 6           139       0.100000           100.415641                    NaN
# 7           141       1.000000            21.259934                    NaN
# ...         ...            ...                  ...                    ...
# 13020     19336      30.604328            30.604026                    NaN
# 13021     19337       8.197073             8.197043                    NaN
# 13022     19338      14.776845            14.776792                    NaN
# 13023     19339     227.327894           227.327287                    NaN
# 13024     19340       7.288449             7.288423                    NaN
#
# ...

# %%
forma_date = df

forma_date['date'] = pd.to_datetime(forma_date.date)

forma_date
# Out:
# /var/folders/fp/yk0vdn2x3czcnj314mr51lzr0000gn/T/ipykernel_42743/3931037494.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forma_date['date'] = pd.to_datetime(forma_date.date)
#        OBJECTID  poly_GISAcres  poly_Acres_AutoCalc  irwin_CalculatedAcres  \
# 0           127     562.913504           562.911767                574.424
# 2           129       0.300000             2.850691                    NaN
# 3           130      44.300517            44.300352                    NaN
# 6           139       0.100000           100.415641                    NaN
# 7           141       1.000000            21.259934                    NaN
# ...         ...            ...                  ...                    ...
# ...

# %%
tmax14_df = pd.read_csv('tmax14.csv')

tmax14_df
# Out:
#         wf_id   wf_date      stat_id  dist_towf_mile  year_date element  \
# 0        9742  20200604  USC00023150          15.110   20200525    TMAX
# 1        9742  20200604  USC00023150          15.110   20200527    TMAX
# 2        9742  20200604  USC00023150          15.110   20200601    TMAX
# 3        9742  20200604  USC00023150          15.110   20200603    TMAX
# 4        9742  20200604  USC00023150          15.110   20200604    TMAX
# ...       ...       ...          ...             ...        ...     ...
# 309017   9960  20210512  USS0012K02S          23.753   20210507    TMAX
# 309018   9960  20210512  USS0012K02S          23.753   20210503    TMAX
# 309019   9960  20210512  USS0012K02S          23.753   20210508    TMAX
# 309020   9960  20210512  USS0012K02S          23.753   20210509    TMAX
# 309021   9960  20210512  USS0012K02S          23.753   20210430    TMAX
#
#         data_value  stat_rank
# 0              317          3
# 1              350          3
# ...

# %% [markdown]
# ## Fixing data that was entered wrong
# * for Tmax data

# %%
tmax14_df1 = tmax14_df

tmax14_df1['temp'] = ((((tmax14_df1['data_value'])-32)*(5/9))*10).where(tmax14_df1['data_value'].between(45,110),tmax14_df1['data_value'])

tmax14_df1
# Out:
#         wf_id   wf_date      stat_id  dist_towf_mile  year_date element  \
# 0        9742  20200604  USC00023150          15.110   20200525    TMAX
# 1        9742  20200604  USC00023150          15.110   20200527    TMAX
# 2        9742  20200604  USC00023150          15.110   20200601    TMAX
# 3        9742  20200604  USC00023150          15.110   20200603    TMAX
# 4        9742  20200604  USC00023150          15.110   20200604    TMAX
# ...       ...       ...          ...             ...        ...     ...
# 309017   9960  20210512  USS0012K02S          23.753   20210507    TMAX
# 309018   9960  20210512  USS0012K02S          23.753   20210503    TMAX
# 309019   9960  20210512  USS0012K02S          23.753   20210508    TMAX
# 309020   9960  20210512  USS0012K02S          23.753   20210509    TMAX
# 309021   9960  20210512  USS0012K02S          23.753   20210430    TMAX
#
#         data_value  stat_rank        temp
# 0              317          3  317.000000
# ...

# %%
tmax14_df1['tempF'] = tmax14_df1['temp'].apply(lambda x: ((x/10)* (9/5)) + 32)

tmax14_df1
# Out:
#         wf_id   wf_date      stat_id  dist_towf_mile  year_date element  \
# 0        9742  20200604  USC00023150          15.110   20200525    TMAX
# 1        9742  20200604  USC00023150          15.110   20200527    TMAX
# 2        9742  20200604  USC00023150          15.110   20200601    TMAX
# 3        9742  20200604  USC00023150          15.110   20200603    TMAX
# 4        9742  20200604  USC00023150          15.110   20200604    TMAX
# ...       ...       ...          ...             ...        ...     ...
# 309017   9960  20210512  USS0012K02S          23.753   20210507    TMAX
# 309018   9960  20210512  USS0012K02S          23.753   20210503    TMAX
# 309019   9960  20210512  USS0012K02S          23.753   20210508    TMAX
# 309020   9960  20210512  USS0012K02S          23.753   20210509    TMAX
# 309021   9960  20210512  USS0012K02S          23.753   20210430    TMAX
#
#         data_value  stat_rank        temp   tempF
# 0              317          3  317.000000   89.06
# ...

# %%
tmax14_df1.dtypes
# Out:
# wf_id               int64
# wf_date             int64
# stat_id            object
# dist_towf_mile    float64
# year_date           int64
# element            object
# data_value          int64
# stat_rank           int64
# temp              float64
# tempF             float64
# dtype: object

# %%
# Convert to datetime (if not already)
tmax14_df1['wf_date'] = pd.to_datetime(tmax14_df1['wf_date'], format='%Y%m%d')

# %%
tmax14_df1
# Out:
#         wf_id    wf_date      stat_id  dist_towf_mile  year_date element  \
# 0        9742 2020-06-04  USC00023150          15.110   20200525    TMAX
# 1        9742 2020-06-04  USC00023150          15.110   20200527    TMAX
# 2        9742 2020-06-04  USC00023150          15.110   20200601    TMAX
# 3        9742 2020-06-04  USC00023150          15.110   20200603    TMAX
# 4        9742 2020-06-04  USC00023150          15.110   20200604    TMAX
# ...       ...        ...          ...             ...        ...     ...
# 309017   9960 2021-05-12  USS0012K02S          23.753   20210507    TMAX
# 309018   9960 2021-05-12  USS0012K02S          23.753   20210503    TMAX
# 309019   9960 2021-05-12  USS0012K02S          23.753   20210508    TMAX
# 309020   9960 2021-05-12  USS0012K02S          23.753   20210509    TMAX
# 309021   9960 2021-05-12  USS0012K02S          23.753   20210430    TMAX
#
#         data_value  stat_rank        temp   tempF
# ...

# %%
tmax14_df1['year_date'] = pd.to_datetime(tmax14_df1['year_date'], format='%Y%m%d')

# %%
tmax14_df1
# Out:
#         wf_id    wf_date      stat_id  dist_towf_mile  year_date element  \
# 0        9742 2020-06-04  USC00023150          15.110 2020-05-25    TMAX
# 1        9742 2020-06-04  USC00023150          15.110 2020-05-27    TMAX
# 2        9742 2020-06-04  USC00023150          15.110 2020-06-01    TMAX
# 3        9742 2020-06-04  USC00023150          15.110 2020-06-03    TMAX
# 4        9742 2020-06-04  USC00023150          15.110 2020-06-04    TMAX
# ...       ...        ...          ...             ...        ...     ...
# 309017   9960 2021-05-12  USS0012K02S          23.753 2021-05-07    TMAX
# 309018   9960 2021-05-12  USS0012K02S          23.753 2021-05-03    TMAX
# 309019   9960 2021-05-12  USS0012K02S          23.753 2021-05-08    TMAX
# 309020   9960 2021-05-12  USS0012K02S          23.753 2021-05-09    TMAX
# 309021   9960 2021-05-12  USS0012K02S          23.753 2021-04-30    TMAX
#
#         data_value  stat_rank        temp   tempF
# ...

# %%
tmax14_df2 = tmax14_df1
tmax14_df2
# Out:
#         wf_id    wf_date      stat_id  dist_towf_mile  year_date element  \
# 0        9742 2020-06-04  USC00023150          15.110 2020-05-25    TMAX
# 1        9742 2020-06-04  USC00023150          15.110 2020-05-27    TMAX
# 2        9742 2020-06-04  USC00023150          15.110 2020-06-01    TMAX
# 3        9742 2020-06-04  USC00023150          15.110 2020-06-03    TMAX
# 4        9742 2020-06-04  USC00023150          15.110 2020-06-04    TMAX
# ...       ...        ...          ...             ...        ...     ...
# 309017   9960 2021-05-12  USS0012K02S          23.753 2021-05-07    TMAX
# 309018   9960 2021-05-12  USS0012K02S          23.753 2021-05-03    TMAX
# 309019   9960 2021-05-12  USS0012K02S          23.753 2021-05-08    TMAX
# 309020   9960 2021-05-12  USS0012K02S          23.753 2021-05-09    TMAX
# 309021   9960 2021-05-12  USS0012K02S          23.753 2021-04-30    TMAX
#
#         data_value  stat_rank        temp   tempF
# ...

# %%
# Sort in correct order
tmax14_df2 = tmax14_df2.sort_values(['wf_id', 'stat_rank', 'year_date'], ascending=[False,True,False], ignore_index=True)

tmax14_df2
# Out:
#         wf_id    wf_date      stat_id  dist_towf_mile  year_date element  \
# 0       19340 2022-08-25  USR0000TBAS          19.376 2022-08-25    TMAX
# 1       19340 2022-08-25  USR0000TBAS          19.376 2022-08-24    TMAX
# 2       19340 2022-08-25  USR0000TBAS          19.376 2022-08-23    TMAX
# 3       19340 2022-08-25  USR0000TBAS          19.376 2022-08-22    TMAX
# 4       19340 2022-08-25  USR0000TBAS          19.376 2022-08-21    TMAX
# ...       ...        ...          ...             ...        ...     ...
# 309017    127 2021-05-04  USC00044555          19.810 2021-04-25    TMAX
# 309018    127 2021-05-04  USC00044555          19.810 2021-04-24    TMAX
# 309019    127 2021-05-04  USC00044555          19.810 2021-04-23    TMAX
# 309020    127 2021-05-04  USC00044555          19.810 2021-04-22    TMAX
# 309021    127 2021-05-04  USC00044555          19.810 2021-04-21    TMAX
#
#         data_value  stat_rank   temp  tempF
# 0              333          1  333.0  91.94
# ...

# %% [markdown]
# ## Ranking days by day

# %%
# Calculate Ranking per Group
tmax14_df2['Date Order'] = (
    tmax14_df2.groupby(['wf_id', 'stat_rank'])['year_date'].apply(
        lambda s: s.diff().lt(pd.Timedelta(days=1)).cumsum() + 1
    )
)

tmax14_df2.head(50)
# Out:
#     wf_id    wf_date      stat_id  dist_towf_mile  year_date element  \
# 0   19340 2022-08-25  USR0000TBAS          19.376 2022-08-25    TMAX
# 1   19340 2022-08-25  USR0000TBAS          19.376 2022-08-24    TMAX
# 2   19340 2022-08-25  USR0000TBAS          19.376 2022-08-23    TMAX
# 3   19340 2022-08-25  USR0000TBAS          19.376 2022-08-22    TMAX
# 4   19340 2022-08-25  USR0000TBAS          19.376 2022-08-21    TMAX
# 5   19340 2022-08-25  USR0000TBAS          19.376 2022-08-20    TMAX
# 6   19340 2022-08-25  USR0000TBAS          19.376 2022-08-19    TMAX
# 7   19340 2022-08-25  USR0000TBAS          19.376 2022-08-18    TMAX
# 8   19340 2022-08-25  USR0000TBAS          19.376 2022-08-17    TMAX
# 9   19340 2022-08-25  USR0000TBAS          19.376 2022-08-16    TMAX
# 10  19340 2022-08-25  USR0000TBAS          19.376 2022-08-15    TMAX
# 11  19340 2022-08-25  USR0000TBAS          19.376 2022-08-14    TMAX
# 12  19340 2022-08-25  USR0000TBAS          19.376 2022-08-13    TMAX
# ...

# %%
tmax14_df3 = tmax14_df2

# %%
tmax14_df3.drop(columns=['wf_date','temp','element'])
tmax14_df3
# Out:
#         wf_id    wf_date      stat_id  dist_towf_mile  year_date element  \
# 0       19340 2022-08-25  USR0000TBAS          19.376 2022-08-25    TMAX
# 1       19340 2022-08-25  USR0000TBAS          19.376 2022-08-24    TMAX
# 2       19340 2022-08-25  USR0000TBAS          19.376 2022-08-23    TMAX
# 3       19340 2022-08-25  USR0000TBAS          19.376 2022-08-22    TMAX
# 4       19340 2022-08-25  USR0000TBAS          19.376 2022-08-21    TMAX
# ...       ...        ...          ...             ...        ...     ...
# 309017    127 2021-05-04  USC00044555          19.810 2021-04-25    TMAX
# 309018    127 2021-05-04  USC00044555          19.810 2021-04-24    TMAX
# 309019    127 2021-05-04  USC00044555          19.810 2021-04-23    TMAX
# 309020    127 2021-05-04  USC00044555          19.810 2021-04-22    TMAX
# 309021    127 2021-05-04  USC00044555          19.810 2021-04-21    TMAX
#
#         data_value  stat_rank   temp  tempF  Date Order
# ...

# %%
tmax14_df3['full<90']= (
    tmax14_df3.groupby(['wf_id', 'stat_rank'])['tempF'].sum(
    
    )
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [249], in <cell line: 2>()
#       1 tmax14_df3['full<90']= (
# ----> 2     (tmax14_df3.groupby(['wf_id', 'stat_rank'])['tempF'] > 90).sum(
#       3
#       4     )
#       5 )
#
# TypeError: '>' not supported between instances of 'SeriesGroupBy' and 'int'

# %%
tmax14_df3.groupby(['wf_id', 'stat_rank'])['tempF'].mean()
# Out:
# wf_id  stat_rank
# 127    1            77.848571
#        2            78.915714
#        3            74.865714
# 129    1            82.425714
#        2            75.855714
#                       ...
# 19339  2            90.000000
#        3            92.107143
# 19340  1            95.642857
#        2            96.825714
#        3            96.157143
# Name: tempF, Length: 22857, dtype: float64

# %%
tmax14_df4 = tmax14_df3

# %%
tmax14_df4 = tmax14_df4.loc[tmax14_df4['stat_rank'] == 1] 

tmax14_df4
# Out:
#         wf_id    wf_date      stat_id  dist_towf_mile  year_date element  \
# 0       19340 2022-08-25  USR0000TBAS          19.376 2022-08-25    TMAX
# 1       19340 2022-08-25  USR0000TBAS          19.376 2022-08-24    TMAX
# 2       19340 2022-08-25  USR0000TBAS          19.376 2022-08-23    TMAX
# 3       19340 2022-08-25  USR0000TBAS          19.376 2022-08-22    TMAX
# 4       19340 2022-08-25  USR0000TBAS          19.376 2022-08-21    TMAX
# ...       ...        ...          ...             ...        ...     ...
# 308989    127 2021-05-04  USR0000CARR          11.214 2021-04-25    TMAX
# 308990    127 2021-05-04  USR0000CARR          11.214 2021-04-24    TMAX
# 308991    127 2021-05-04  USR0000CARR          11.214 2021-04-23    TMAX
# 308992    127 2021-05-04  USR0000CARR          11.214 2021-04-22    TMAX
# 308993    127 2021-05-04  USR0000CARR          11.214 2021-04-21    TMAX
#
#         data_value  stat_rank   temp  tempF  Date Order
# ...

# %%
tmax14_df4
# Out:
#         wf_id    wf_date      stat_id  dist_towf_mile  year_date element  \
# 0       19340 2022-08-25  USR0000TBAS          19.376 2022-08-25    TMAX
# 1       19340 2022-08-25  USR0000TBAS          19.376 2022-08-24    TMAX
# 2       19340 2022-08-25  USR0000TBAS          19.376 2022-08-23    TMAX
# 3       19340 2022-08-25  USR0000TBAS          19.376 2022-08-22    TMAX
# 4       19340 2022-08-25  USR0000TBAS          19.376 2022-08-21    TMAX
# ...       ...        ...          ...             ...        ...     ...
# 308989    127 2021-05-04  USR0000CARR          11.214 2021-04-25    TMAX
# 308990    127 2021-05-04  USR0000CARR          11.214 2021-04-24    TMAX
# 308991    127 2021-05-04  USR0000CARR          11.214 2021-04-23    TMAX
# 308992    127 2021-05-04  USR0000CARR          11.214 2021-04-22    TMAX
# 308993    127 2021-05-04  USR0000CARR          11.214 2021-04-21    TMAX
#
#         data_value  stat_rank   temp  tempF  Date Order
# ...

# %% [markdown]
# ## Bringing df together

# %%
avg_maxT_df
# Out:
#             mean
# wf_id
# 127    77.848571
# 129    82.425714
# 130    84.290000
# 139    82.425714
# 141    66.264286
# ...          ...
# 19336  94.040000
# 19337  95.642857
# 19338  93.431429
# 19339  93.006154
# 19340  95.642857
#
# [7708 rows x 1 columns]

# %%
days_above90_df
# Out:
#        days>90
# wf_id
# 127          1
# 129          1
# 130          3
# 139          1
# 144          2
# ...        ...
# 19336        2
# 19337       14
# 19338        9
# 19339       12
# 19340       14
#
# [4833 rows x 1 columns]

# %%
wfdf
# Out:
#        poly_Acres_AutoCalc  irwin_InitialLatitude  irwin_InitialLongitude
# wf_id
# 127             562.911767              36.071140             -121.450500
# 128               0.151680              39.556690             -119.558500
# 129               2.850691              33.293840             -110.450000
# 130              44.300352              35.875820             -115.204100
# 136               0.934468              34.455900             -114.371900
# ...                    ...                    ...                     ...
# 19336            30.604026              30.551033              -98.464562
# 19337             8.197043              30.121500              -97.241000
# 19338            14.776792              30.948167              -94.972500
# 19339           227.327287              27.933394              -97.157471
# 19340             7.288423              29.917222              -97.386111
#
# [10734 rows x 3 columns]

# %% [markdown]
# ## join below df
# * avg_maxT_df
# * days_above90_df
# * wfdf

# %%
wfdf = wfdf.join([avg_maxT_df,days_above90_df])

wfdf
# Out:
#        poly_Acres_AutoCalc  irwin_InitialLatitude  irwin_InitialLongitude  \
# wf_id
# 127             562.911767              36.071140             -121.450500
# 128               0.151680              39.556690             -119.558500
# 129               2.850691              33.293840             -110.450000
# 130              44.300352              35.875820             -115.204100
# 136               0.934468              34.455900             -114.371900
# ...                    ...                    ...                     ...
# 19336            30.604026              30.551033              -98.464562
# 19337             8.197043              30.121500              -97.241000
# 19338            14.776792              30.948167              -94.972500
# 19339           227.327287              27.933394              -97.157471
# 19340             7.288423              29.917222              -97.386111
#
#             mean  days>90
# wf_id
# 127    77.848571      1.0
# ...

# %%
fin_df_ita1 = wfdf

fin_df_ita1
# Out:
#        poly_Acres_AutoCalc  irwin_InitialLatitude  irwin_InitialLongitude  \
# wf_id
# 127             562.911767              36.071140             -121.450500
# 129               2.850691              33.293840             -110.450000
# 130              44.300352              35.875820             -115.204100
# 139             100.415641              33.336000             -110.468600
# 144               6.797168              46.145110             -114.045900
# ...                    ...                    ...                     ...
# 19336            30.604026              30.551033              -98.464562
# 19337             8.197043              30.121500              -97.241000
# 19338            14.776792              30.948167              -94.972500
# 19339           227.327287              27.933394              -97.157471
# 19340             7.288423              29.917222              -97.386111
#
#             mean  days>90
# wf_id
# 127    77.848571      1.0
# ...

# %%
pathname = '/Users/christopherobrien/projects2/Wildfires/static_in_fin/fin_df_ita1.csv'


fin_df_ita1.to_csv(pathname)
